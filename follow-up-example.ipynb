# %%
# %matplotlib inline

import counterpart
# Out:
# /home/savchenk/anaconda2/lib/python2.7/site-packages/matplotlib/__init__.py:1405: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)

# %%
reload(counterpart)
# Out:
# <module 'counterpart' from 'counterpart.pyc'>

# %%
le=counterpart.LIGOEvent(
        use_trigger_time="2017-06-08T02:01:16.492188",
        use_gname="G288732",
        use_loc_map_path="/home/savchenk/work/ligo/lvt170608/bayestar.fits"
    ).get()
le.promote()

le.plot_map()
# Out:
# NSIDE = 512
# ORDERING = NESTED in fits file
# INDXSCHM = IMPLICIT
# Ordering converted to RING
# 0.0 180.0 -180.0 180.0
# The interval between parallels is 30 deg -0.00'.
# The interval between meridians is 30 deg -0.00'.

# %%
iv=counterpart.INTEGRALVisibility(use_minsolarangle=40).get()
iv.plot()
print "peak (RA, Dec):",iv.peak_target_visible()
# Out:
# top the object has not record of restore config
# 0.0 180.0 -180.0 180.0
# The interval between parallels is 30 deg -0.00'.
# The interval between meridians is 30 deg -0.00'.
# peak (RA, Dec): (110.56640625, 9.3671571526015782)

# %% [markdown]
# # Count limits

# %%
cl=counterpart.CountLimits().get()
print cl.count_limits
# Out:
# top the object has not record of restore config
# {'hard': {'ISGRI': 80.71441236875, 'SPI-ACS': 1139.4122208292308, 'IBIS/Veto': 1839.167055698158}, 'soft': {'ISGRI': 237.64218181740824, 'SPI-ACS': 3414.957102863812, 'IBIS/Veto': 1839.167055698158}}

# %%
resp=counterpart.Responses().get()
#print cl.count_limits
# Out:
# top the object has not record of restore config
# top the object has not record of restore config

# %%
resp.responses['hard']['SPI-ACS'].min()
# Out:
# 1.4971962029399484e-10

# %%
sens=counterpart.Sensitivities().get()
#print cl.count_limits
# Out:
# top the object has not record of restore config
# top the object has not record of restore config
# top the object has not record of restore config
# top the object has not record of restore config

# %% [markdown]
# # Individual sensitivities, assuming there is no detection

# %%
sens.plot()

# %%
sens.plot_fancy()
# Out:
# to overplot 1
# to overplot [[(array([ 99.99817458,  99.9993018 ,  99.99993502, ..., 100.        ,
#        100.        , 100.        ]), 'k', 90), (array([ 99.99817458,  99.9993018 ,  99.99993502, ..., 100.        ,
#        100.        , 100.        ]), 'k', 50)]]
# op set (array([ 99.99817458,  99.9993018 ,  99.99993502, ..., 100.        ,
#        100.        , 100.        ]), 'k', 90)
# overplotting [[100.         100.         100.         ..., 100.         100.         100.        ]
#  [100.         100.         100.         ..., 100.         100.         100.        ]
#  [100.         100.         100.         ..., 100.         100.         100.        ]
#  ...,
#  [ 99.99961787  99.99962287  99.99962787 ...,  99.99960787  99.99961287
#    99.99961787]
#  [ 99.99961821  99.99962071  99.99962321 ...,  99.99961321  99.99961571
#    99.99961821]
#  [ 99.9993141   99.9993141   99.9993141  ...,  99.9993141   99.9993141
#    99.9993141 ]]
# levels: [90]
# ...

# %%
sens.summarize()
# Out:
# model hard sensitivity extreme from 2.37758154277e-07 to 5.10838389613e-07
# model hard sensitivity within 50% of best contains 0.544970601239
# model soft sensitivity extreme from 8.12249691049e-07 to 2.15932176147e-06
# model soft sensitivity within 50% of best contains 0.573659349453
